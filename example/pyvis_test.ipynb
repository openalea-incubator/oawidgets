# %% [markdown]
# # PyVis Test

# %%
import openalea
from openalea.mtg import *
# %matplotlib notebook
# Out:
# NOT using graph editor observer No module named grapheditor

# %%
g = MTG()
vid = g.add_component(g.root)
random_tree(g, vid, nb_children=2, nb_vertices=20)
g.display()
# Out:
# MTG : nb_vertices=22, nb_scales=2
# /1			(id=1)
# 	+2			(id=2)
# 		+5			(id=5)
# 		^<7			(id=7)
# 		^<12			(id=12)
# 		^<20			(id=20)
# 	^<6			(id=6)
# 		+8			(id=8)
# 			+10			(id=10)
# 			^<21			(id=21)
# 		^<11			(id=11)
# 			+16			(id=16)
# 		^<17			(id=17)
# 			+18			(id=18)
# 		^<19			(id=19)
# 	^<9			(id=9)
# ^<3			(id=3)
# ^<4			(id=4)
# ^<13			(id=13)
# 	+14			(id=14)
# ^<15			(id=15)

# %%
from openalea.mtg import draw
draw.draw(g)
# Out:
# <img src="data:image/png;base64,...">

# %%
from oawidgets.mtg import plot
plot(g, hlayout=True)
# Out:
#         <iframe
#             width="900px"
#             height="800px"
#             src="mtg.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from openalea.deploy.shared_data import shared_data
data = shared_data(openalea.mtg)

# %%
data.glob('*.mtg')
# Out:
# [Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/agraf.mtg'),
#  Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/apricot.mtg'),
#  Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/boutdenoylum2.mtg'),
#  Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/braeburn.mtg'),
#  Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/monopodial_plant.mtg'),
#  Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/mtg1.mtg'),
#  Path(u'/home/bbrument/miniconda3/envs/notebook_env/lib/python2.7/site-packages/openalea.mtg-2.0.1-py2.7.egg/share/data/mtg2.mtg'),
# ...

# %%
g_oth = MTG(data/'boutdenoylum2.mtg')
print(g_oth.nb_vertices(scale=g_oth.max_scale()))
g_oth.max_scale()

draw.draw(g_oth)
# Out:
# 198
# <img src="data:image/png;base64,...">

# %%
plot(g_oth)
# Out:
#         <iframe
#             width="900px"
#             height="800px"
#             src="mtg.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
root = g_oth.roots_iter(scale=g_oth.max_scale()).next()
g_oth.Trunk(root)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 31]

# %%
g.roots_iter(scale=g.max_scale())
